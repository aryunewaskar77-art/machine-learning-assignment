# %%
import pandas as pd
t = pd.read_csv('/Users/aaryaanewaskar/Desktop/Study/ML Year 2/classNotes/Titanic-Dataset.csv')

# %% [markdown]
# ## Question 1 :
# Load the dataset into t. How many rows and how many columns does it have?

# %%
print(t.shape)
print("rows: ", t.shape[0])
print("columns: ", t.shape[1])
# Out:
# (891, 12)
# rows:  891
# columns:  12

# %% [markdown]
# ## Question 2 :
# Print all the column names. Pick any three and write in a comment what you think each one holds.

# %%
print(t.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %% [markdown]
# ## Question 3 :
# Display the first 7 rows and the last 3 rows.

# %%
print(t.head(7))
print(t.tail(3))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## Question 4 :
# Run t.info(). Some columns have fewer values than the total number of rows. Write down which
# columns those are, and how many values are missing from each. ★

# %%
t.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# ## Question 5 :
# Run t.describe(). It shows fewer columns than info() listed. Write down two columns it left out,
# and explain why.

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Question 6 :
# For the class column, answer all three questions below using a different function for each:
# (a) how many different values are there?
# (b) what are they?
# (c) how many passengers fall into each one?

# %%
print(t['Pclass'].nunique())
print(t['Pclass'].unique())
print(t['Pclass'].value_counts())
# Out:
# 3
# [3 1 2]
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ## Question 7 :
# Find how many passengers were male and how many were female.

# %%
print(t['Sex'].value_counts())
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ## Question 8 :
# In describe(), look at the age column. Compare its mean with its 50% value. Which is larger, and
# what does that suggest about the passengers' ages? ★

# %%
mean_age = t['Age'].mean()
median_age = t['Age'].median()
print(mean_age, median_age)
# Out:
# 29.69911764705882 28.0

# %% [markdown]
# ## Question 9 :
# (Challenge) The age column has missing values. Using only shape and info(), work out what
# percentage of age values are missing. Write the number in a comment.

# %%
total_rows=t.shape[0]
age_values=714
missing_age=total_rows-age_values
percentage_missing_age=(missing_age/total_rows)*100
print(percentage_missing_age)
# Out:
# 19.865319865319865
